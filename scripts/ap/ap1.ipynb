# %%
from GammaAP import *
ap = GammaAP()
# %matplotlib widget

# %%
absolutepath="/Users/bulgarelli/projects/AGILE/aperturePhotometry/"
source="3C454.3"
relativepath="E1"

path=absolutepath + source + "/" + relativepath + "/"

#IGR J17354-3255
#gasvalue = 0.00054
#gal=0.7
#iso=8

#Vela
#gasvalue = 0.00018
#gal=0.7
#iso=8

#3C454.4
gasvalue = 0
gal=0.7
iso=8

#CTA 102
#gasvalue = 0
#gal=0.7
#iso=8

# %%
filenameAP = path + "E1dq1_86400s_emin100_emax10000_r4.ap"
print(filenameAP)
# Out:
# /Users/bulgarelli/projects/AGILE/aperturePhotometry/3C454.3/E1/E1dq1_86400s_emin100_emax10000_r4.ap

# %%
#generation of .ap4

# %%
ap.normalizeAP(filenameAP, ranal=4, gasvalue=gasvalue, gal=gal, iso=iso, gindex=2.1, writevonmissesfiles=0)

# %%
from DisplayLC import *

# %%
apdisplay = DisplayLC()

# %%
apdisplay.display(1, 0, 1000, 55153, 55183, filenameAP + ".ap4")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d8a4b27075d5> in <module>
# ----> 1 apdisplay.display(1, 0, 1000, 55153, 55183, filenameAP + ".ap4")
#
# NameError: name 'filenameAP' is not defined

# %%
apdisplay.time_tt_to_mjd(185587200.0)
# Out:
# 55153.0

# %%
! cat /Users/bulgarelli/projects/AGILE/aperturePhotometry/3C454.3/E1/E1dq1_86400s_emin100_emax10000_r4.ap

# %%
apdisplay.display("2", 0, 1000, -1, -1, "/Users/bulgarelli/projects/AGILE/aperturePhotometry/3C454.3/E1/E1dq1_86400s_emin100_emax10000_pl218n.mle.lc", "/Users/bulgarelli/projects/AGILE/aperturePhotometry/3C454.3/E1/E1dq1_86400s_emin100_emax10000_pl218.fermi.lc")
# Out:
# 30
# 30
# /Users/bulgarelli/opt/anaconda3/envs/agilepy2/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /Users/bulgarelli/opt/anaconda3/envs/agilepy2/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /Users/bulgarelli/opt/anaconda3/envs/agilepy2/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /Users/bulgarelli/opt/anaconda3/envs/agilepy2/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# ...
