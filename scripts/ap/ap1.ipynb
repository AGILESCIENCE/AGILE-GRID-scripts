# %%
import os
import sys
# Aggiungi il percorso alla directory contenente la tua libreria
absolutepath="/shared_dir/3C4543/"
library_path = os.path.abspath('/shared_dir/3C4543/AGILE-GRID-scripts/scripts/ap/')
if library_path not in sys.path:
    sys.path.insert(0, library_path)

# %%
from GammaAP import *
ap = GammaAP()
# %matplotlib widget

# %%
relativepath="E2"

path=absolutepath + "/" + relativepath

#IGR J17354-3255
#gasvalue = 0.00054
#gal=0.7
#iso=8

#Vela
#gasvalue = 0.00018
#gal=0.7
#iso=8

#3C454.4
gasvalue = 0
gal=0.7
iso=8

#CTA 102
#gasvalue = 0
#gal=0.7
#iso=8

# %%
filenameAP_86400 = path + "/AP/AGILE/E2dq1_86400s_emin100_emax10000_r4.ap"
filenameAP_43200 = path + "/AP/AGILE/E2dq1_43200s_emin100_emax10000_r4.ap"
filenameAP_21600 = path + "/AP/AGILE/E2dq1_21600s_emin100_emax10000_r4.ap"

# %%
#generation of .ap4

# %%
ap.normalizeAP(filenameAP_86400, ranal=4, gasvalue=gasvalue, gal=gal, iso=iso, gindex=2.1, writevonmissesfiles=0)
ap.normalizeAP(filenameAP_43200, ranal=4, gasvalue=gasvalue, gal=gal, iso=iso, gindex=2.1, writevonmissesfiles=0)
ap.normalizeAP(filenameAP_21600, ranal=4, gasvalue=gasvalue, gal=gal, iso=iso, gindex=2.1, writevonmissesfiles=0)
# Out:
# Loading data.../shared_dir/3C4543//E2/AP/AGILE/E2dq1_86400s_emin100_emax10000_r4.ap
# S@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [2.68555935e-01 1.00000179e+00 2.43039290e+05]
# E@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# rateWeightedMean1:          6.749e-06
# rateWeightedMean2:          1.000e-05
# rateWeightedMean3:          1.069e-05
# rateWeightedMean4 bkgmodel: 1.224e-06
# rateWeightedMean4 bkgmodel: 0.0000012244418893200
# rateWeightedMean1aa:        1.000e-05
# S@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# ###########################################
# #           getFluxScaleFactor            #
# ###########################################
# input ranal 4.00
# input emin [MeV]: 100
# input emax [MeV]: 10000
# input selected ranal: 4.0
# [2.68555935e-01 1.00000179e+00 2.43039290e+05]
# ###########################################
# #              SOURCE PSF2                #
# ###########################################
# # - Energy min [MeV] = 100
# # - Energy max [MeV] = 10000
# # - photon index [E^-gamma] = 2.10
# # - source off-axis [deg.] = 30
# # - source azimuthal angle [deg.] = 0
# # - PSF scale factor [deg.] = 0.8046
# ###########################################
# Fluxscalefactor2 (king)  based on PSF enclosed fraction: 0.8046
# Fluxscalefactor based on expfluxcorrection (correction for expsoure spectra factor): 1.00
# Total fluxscalefactor: 0.8046
# ###########################################
# E@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# * Res column number:  0:normrateAB11 1:normrateAB12 2:normrateAB13 3:normrateAB14 4:normrateAB21 5:normrateAB22 6:normrateAB23 7:normrateAB24 8:normrateAB11aa 9:normrateAB21aa 10:ratediffR1 11:ratediffR2 12:ratediffR3 13:ratediffR4 14:ratediffR1AA 15:rate 16:rateError 17:flux_ratediffR4 18:flux_ratediffR4Error 19:Sa 20:flux_rate 21:flux_rateError 22:cts_rateWeightedMeanR4 23:Slm 24:SignUL 25:ctsSourceUL 26:rateUL 27:fluxUL 28:SignSens3 29:ctsSourceSens3 30:rateSens3 31:fluxSens3 32:SignSens4 33:ctsSourceSens4 34:rateSens4 35:fluxSens4 36:SignSens5 36:ctsSourceSens5 38:rateSens5 39:fluxSens5 40:fluxscalefactor 41:rateWeightedMeanR1 42:rateWeightedMeanR2 43:rateWeightedMeanR3 44:rateWeightedMeanR4 45:rateWeightedMeanR1aa 46:expBasedRateError 47:temporalBinSize
# AP4 file column number: 0:tstart 1:tstop 2:exp[cm2s] 3:cts 4:normrateAB11 5:normrateAB12 6:normrateAB13 7:normrateAB14 8:normrateAB21 9:normrateAB22 10:normrateAB23 11:normrateAB24 12:normrateAB11aa 13:normrateAB21aa 14:ratediffR1 15:ratediffR2 16:ratediffR3 17:ratediffR4 18:ratediffR1AA 19:rate 20:rateError 21:flux_ratediffR4 22:flux_ratediffR4Error 23:Sa 24:flux_rate 25:flux_rateError 26:cts_rateWeightedMeanR4 27:Slm 28:SignUL 29:ctsSourceUL 30:rateUL 31:fluxUL 32:SignSens3 33:ctsSourceSens3 34:rateSens3 35:fluxSens3 36:SignSens4 37:ctsSourceSens4 38:rateSens4 39:fluxSens4 40:SignSens5 41:ctsSourceSens5 42:rateSens5 43:fluxSens5 44:fluxscalefactor 45:rateWeightedMeanR1 46:rateWeightedMeanR2 47:rateWeightedMeanR3 48:rateWeightedMeanR4 49:rateWeightedMeanR1aa 50:expBasedRateError 51:temporalBinSize
# * Write AP4 file: /shared_dir/3C4543//E2/AP/AGILE/E2dq1_86400s_emin100_emax10000_r4.ap.ap4
# End normalisation
# Loading data.../shared_dir/3C4543//E2/AP/AGILE/E2dq1_43200s_emin100_emax10000_r4.ap
# S@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [2.68555935e-01 1.00000179e+00 2.43039290e+05]
# E@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# rateWeightedMean1:          6.369e-06
# rateWeightedMean2:          9.891e-06
# rateWeightedMean3:          1.069e-05
# rateWeightedMean4 bkgmodel: 1.224e-06
# rateWeightedMean4 bkgmodel: 0.0000012244418893200
# rateWeightedMean1aa:        9.891e-06
# S@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# ###########################################
# #           getFluxScaleFactor            #
# ###########################################
# input ranal 4.00
# input emin [MeV]: 100
# input emax [MeV]: 10000
# input selected ranal: 4.0
# [2.68555935e-01 1.00000179e+00 2.43039290e+05]
# ###########################################
# #              SOURCE PSF2                #
# ###########################################
# # - Energy min [MeV] = 100
# # - Energy max [MeV] = 10000
# # - photon index [E^-gamma] = 2.10
# # - source off-axis [deg.] = 30
# # - source azimuthal angle [deg.] = 0
# # - PSF scale factor [deg.] = 0.8046
# ###########################################
# Fluxscalefactor2 (king)  based on PSF enclosed fraction: 0.8046
# Fluxscalefactor based on expfluxcorrection (correction for expsoure spectra factor): 1.00
# Total fluxscalefactor: 0.8046
# ###########################################
# E@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# * Res column number:  0:normrateAB11 1:normrateAB12 2:normrateAB13 3:normrateAB14 4:normrateAB21 5:normrateAB22 6:normrateAB23 7:normrateAB24 8:normrateAB11aa 9:normrateAB21aa 10:ratediffR1 11:ratediffR2 12:ratediffR3 13:ratediffR4 14:ratediffR1AA 15:rate 16:rateError 17:flux_ratediffR4 18:flux_ratediffR4Error 19:Sa 20:flux_rate 21:flux_rateError 22:cts_rateWeightedMeanR4 23:Slm 24:SignUL 25:ctsSourceUL 26:rateUL 27:fluxUL 28:SignSens3 29:ctsSourceSens3 30:rateSens3 31:fluxSens3 32:SignSens4 33:ctsSourceSens4 34:rateSens4 35:fluxSens4 36:SignSens5 36:ctsSourceSens5 38:rateSens5 39:fluxSens5 40:fluxscalefactor 41:rateWeightedMeanR1 42:rateWeightedMeanR2 43:rateWeightedMeanR3 44:rateWeightedMeanR4 45:rateWeightedMeanR1aa 46:expBasedRateError 47:temporalBinSize
# AP4 file column number: 0:tstart 1:tstop 2:exp[cm2s] 3:cts 4:normrateAB11 5:normrateAB12 6:normrateAB13 7:normrateAB14 8:normrateAB21 9:normrateAB22 10:normrateAB23 11:normrateAB24 12:normrateAB11aa 13:normrateAB21aa 14:ratediffR1 15:ratediffR2 16:ratediffR3 17:ratediffR4 18:ratediffR1AA 19:rate 20:rateError 21:flux_ratediffR4 22:flux_ratediffR4Error 23:Sa 24:flux_rate 25:flux_rateError 26:cts_rateWeightedMeanR4 27:Slm 28:SignUL 29:ctsSourceUL 30:rateUL 31:fluxUL 32:SignSens3 33:ctsSourceSens3 34:rateSens3 35:fluxSens3 36:SignSens4 37:ctsSourceSens4 38:rateSens4 39:fluxSens4 40:SignSens5 41:ctsSourceSens5 42:rateSens5 43:fluxSens5 44:fluxscalefactor 45:rateWeightedMeanR1 46:rateWeightedMeanR2 47:rateWeightedMeanR3 48:rateWeightedMeanR4 49:rateWeightedMeanR1aa 50:expBasedRateError 51:temporalBinSize
# * Write AP4 file: /shared_dir/3C4543//E2/AP/AGILE/E2dq1_43200s_emin100_emax10000_r4.ap.ap4
# End normalisation
# Loading data.../shared_dir/3C4543//E2/AP/AGILE/E2dq1_21600s_emin100_emax10000_r4.ap
# S@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [2.68555935e-01 1.00000179e+00 2.43039290e+05]
# E@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# rateWeightedMean1:          5.461e-06
# rateWeightedMean2:          9.947e-06
# rateWeightedMean3:          1.069e-05
# rateWeightedMean4 bkgmodel: 1.224e-06
# rateWeightedMean4 bkgmodel: 0.0000012244418893200
# rateWeightedMean1aa:        9.947e-06
# S@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# ###########################################
# #           getFluxScaleFactor            #
# ###########################################
# input ranal 4.00
# input emin [MeV]: 100
# input emax [MeV]: 10000
# input selected ranal: 4.0
# [2.68555935e-01 1.00000179e+00 2.43039290e+05]
# ###########################################
# #              SOURCE PSF2                #
# ###########################################
# # - Energy min [MeV] = 100
# # - Energy max [MeV] = 10000
# # - photon index [E^-gamma] = 2.10
# # - source off-axis [deg.] = 30
# # - source azimuthal angle [deg.] = 0
# # - PSF scale factor [deg.] = 0.8046
# ###########################################
# Fluxscalefactor2 (king)  based on PSF enclosed fraction: 0.8046
# Fluxscalefactor based on expfluxcorrection (correction for expsoure spectra factor): 1.00
# Total fluxscalefactor: 0.8046
# ###########################################
# E@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# * Res column number:  0:normrateAB11 1:normrateAB12 2:normrateAB13 3:normrateAB14 4:normrateAB21 5:normrateAB22 6:normrateAB23 7:normrateAB24 8:normrateAB11aa 9:normrateAB21aa 10:ratediffR1 11:ratediffR2 12:ratediffR3 13:ratediffR4 14:ratediffR1AA 15:rate 16:rateError 17:flux_ratediffR4 18:flux_ratediffR4Error 19:Sa 20:flux_rate 21:flux_rateError 22:cts_rateWeightedMeanR4 23:Slm 24:SignUL 25:ctsSourceUL 26:rateUL 27:fluxUL 28:SignSens3 29:ctsSourceSens3 30:rateSens3 31:fluxSens3 32:SignSens4 33:ctsSourceSens4 34:rateSens4 35:fluxSens4 36:SignSens5 36:ctsSourceSens5 38:rateSens5 39:fluxSens5 40:fluxscalefactor 41:rateWeightedMeanR1 42:rateWeightedMeanR2 43:rateWeightedMeanR3 44:rateWeightedMeanR4 45:rateWeightedMeanR1aa 46:expBasedRateError 47:temporalBinSize
# AP4 file column number: 0:tstart 1:tstop 2:exp[cm2s] 3:cts 4:normrateAB11 5:normrateAB12 6:normrateAB13 7:normrateAB14 8:normrateAB21 9:normrateAB22 10:normrateAB23 11:normrateAB24 12:normrateAB11aa 13:normrateAB21aa 14:ratediffR1 15:ratediffR2 16:ratediffR3 17:ratediffR4 18:ratediffR1AA 19:rate 20:rateError 21:flux_ratediffR4 22:flux_ratediffR4Error 23:Sa 24:flux_rate 25:flux_rateError 26:cts_rateWeightedMeanR4 27:Slm 28:SignUL 29:ctsSourceUL 30:rateUL 31:fluxUL 32:SignSens3 33:ctsSourceSens3 34:rateSens3 35:fluxSens3 36:SignSens4 37:ctsSourceSens4 38:rateSens4 39:fluxSens4 40:SignSens5 41:ctsSourceSens5 42:rateSens5 43:fluxSens5 44:fluxscalefactor 45:rateWeightedMeanR1 46:rateWeightedMeanR2 47:rateWeightedMeanR3 48:rateWeightedMeanR4 49:rateWeightedMeanR1aa 50:expBasedRateError 51:temporalBinSize
# * Write AP4 file: /shared_dir/3C4543//E2/AP/AGILE/E2dq1_21600s_emin100_emax10000_r4.ap.ap4
# End normalisation
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from DisplayLC import *

# %%
apdisplay = DisplayLC()

# %%
filenameAP4_86400 = filenameAP_86400 + ".ap4"
filenameAP4_43200 = filenameAP_43200 + ".ap4"
filenameAP4_21600 = filenameAP_21600 + ".ap4"

# %%
apdisplay.display("1", 0, -1, 55495, 55524, filenameAP4_86400)
# Out:
# 55495.0
# 55496.0
# 55497.0
# 55498.0
# 55499.0
# 55500.0
# 55501.0
# 55502.0
# 55503.0
# 55504.0
# 55505.0
# 55506.0
# 55507.0
# 55508.0
# 55509.0
# 55510.0
# 55511.0
# 55512.0
# 55513.0
# 55514.0
# 55515.0
# 55516.0
# 55517.0
# 55518.0
# 55519.0
# 55520.0
# 55521.0
# 55522.0
# 55523.0
# 55524.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
apdisplay.time_tt_to_mjd(185587200.0)
# Out:
# 55153.0

# %%
! ls "/shared_dir/3C4543/E2/LC/AGILE/"
! ls "/shared_dir/3C4543/E2/LC/FERMI/"
# Out:
# E2dq1_86400s_emin100_emax10000.mle.lc
# E2dq1_86400s_emin100_emax10000_2.mle.lc
# E2dq1_86400s_emin100_emax10000_e18.mle.lc
# E2dq1_86400s_emin100_emax10000_pl218m.mle.lc
# E2dq1_86400s_emin100_emax10000_pl218n.mle.lc
# E2dq1_86400s_emin100_emax50000_f18.mle.lc
# E2dq1_86400s_emin100_emax50000_g.mle.lc
# E2dq1_86400s_emin100_emax50000_h.mle.lc
# E2dq1_86400s_emin100_emax50000_i.mle.lc
# lightcurve3C.mle.lc
# lightcurve3C.mle2.lc
# E2dq1_86400s_emin100_emax10000.fermi.lc
# E2dq1_86400s_emin100_emax10000_2.fermi.lc
# E2dq1_86400s_emin100_emax10000_a_plcbkgfree.fermi.lc
# E2dq1_86400s_emin100_emax10000_e2b1.fermi.lc
# E2dq1_86400s_emin100_emax10000_e2b2.fermi.lc
# E2dq1_86400s_emin100_emax10000_pl218.fermi.lc
# E2dq1_86400s_emin100_emax10000_plcfreebkgfixed.fermi.lc
# E2dq1_86400s_emin100_emax10000_plcfreebkgfree.fermi.lc

# %%
filenameLCAGILE = path + "/LC/AGILE/E2dq1_86400s_emin100_emax10000_2.mle.lc"
print(filenameLCAGILE)
#filenameLCAGILE = path + "/LC/AGILE/lightcurve3C.mle2.lc" #TODO
#print(filenameLCAGILE)
filenameLCFERMI = path + "/LC/FERMI/E2dq1_86400s_emin100_emax10000_e2b1.fermi.lc"
print(filenameLCFERMI)
filenameLCFERMI2 = path + "/LC/FERMI2/SPECTRA2_LC_ts9.fermi2.lc"
print(filenameLCFERMI2)
filenameAPFERMI_025 = path + "/AP/FERMI/lc_3ce2_025d_allmetbkg.fermi.ap"
print(filenameAPFERMI_025) 
filenameAPFERMI_05 = path + "/AP/FERMI/lc_3ce2_0.5d_allmetbkgIGR.fermi.ap"
print(filenameAPFERMI_05) 
filenameAPFERMI_1 = path + "/AP/FERMI/lc_3ce2_1d_allmetbkg.fermi.ap"
print(filenameAPFERMI_1)
# Out:
# /shared_dir/3C4543//E2/LC/AGILE/E2dq1_86400s_emin100_emax10000_2.mle.lc
# /shared_dir/3C4543//E2/LC/FERMI/E2dq1_86400s_emin100_emax10000_e2b1.fermi.lc
# /shared_dir/3C4543//E2/LC/FERMI2/SPECTRA2_LC_ts9.fermi2.lc
# /shared_dir/3C4543//E2/AP/FERMI/lc_3ce2_025d_allmetbkg.fermi.ap
# /shared_dir/3C4543//E2/AP/FERMI/lc_3ce2_0.5d_allmetbkgIGR.fermi.ap
# /shared_dir/3C4543//E2/AP/FERMI/lc_3ce2_1d_allmetbkg.fermi.ap

# %%
apdisplay.display("1", 0, -1, -1, -1, filenameAPFERMI_05)
# Out:
# /home/flareadvocate/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2093: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
apdisplay.display("2", 0, -1, 55495, 55524, filenameAP4_21600, filenameAPFERMI_025)
# Out:
# 55495.0
# 55495.25
# 55495.5
# 55495.75
# 55496.0
# 55496.25
# 55496.5
# 55496.75
# 55497.0
# 55497.25
# 55497.5
# 55498.0
# 55498.25
# 55498.5
# 55498.75
# 55499.0
# 55499.25
# 55499.5
# 55499.75
# 55500.0
# 55500.25
# 55500.5
# 55500.75
# 55501.0
# 55501.25
# 55501.5
# 55501.75
# 55502.0
# 55502.25
# 55502.5
# 55502.75
# 55503.0
# 55503.25
# 55503.5
# 55503.75
# 55504.0
# 55504.25
# 55504.5
# 55504.75
# 55505.0
# 55505.25
# 55505.5
# 55505.75
# 55506.0
# 55506.25
# 55506.5
# 55506.75
# 55507.0
# 55507.25
# 55507.5
# 55507.75
# 55508.0
# 55508.25
# 55508.5
# 55508.75
# 55509.0
# 55509.25
# 55509.5
# 55509.75
# 55510.0
# 55510.25
# 55510.5
# 55510.75
# 55511.0
# 55511.25
# 55511.5
# 55511.75
# 55512.0
# 55512.25
# 55512.5
# 55512.75
# 55513.0
# 55513.25
# 55513.5
# 55513.75
# 55514.0
# 55514.25
# 55514.5
# 55514.75
# 55515.0
# 55515.25
# 55515.5
# 55515.75
# 55516.0
# 55516.25
# 55516.5
# 55516.75
# 55517.0
# 55517.25
# 55517.75
# 55518.0
# 55518.25
# 55518.5
# 55518.75
# 55519.0
# 55519.25
# 55519.5
# 55519.75
# 55520.0
# 55520.25
# 55520.5
# 55520.75
# 55521.0
# 55521.25
# 55521.5
# 55521.75
# 55522.0
# 55522.25
# 55522.5
# 55522.75
# 55523.0
# 55523.25
# 55523.5
# 55523.75
# 55524.0
# 55524.25
# continue
# 55524.5
# continue
# 55524.75
# continue
# 115
# 117
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
