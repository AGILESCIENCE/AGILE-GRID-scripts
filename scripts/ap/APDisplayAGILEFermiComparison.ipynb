# %% [markdown]
# # APDisplayAGILEFermiComparison

# %% [markdown]
# ## Import

# %%
from APDisplayAGILEFermiComparison import APDisplayAGILEFermiComparison

# %% [markdown]
# ## Class init

# %% [markdown]
# APDisplayAGILEFermiComparison()

# %%
apd = APDisplayAGILEFermiComparison()

# %% [markdown]
# ### Loading and plotting data

# %% [markdown]
# load_and_plot(agile_ap, fermi_ap, tstart, tstop, offaxis_txt, lines_list, plotrate_bool)

# %%
apd.load_and_plot("AGILE3.ap4", "FERMI5.ap4",55599.0, 55600.0, '/home/antonio/Desktop/task_ap3/dir_4_60.0_55597.0_55601.0', [55599.2, 55599.3,55599.4,55599.5])
# Out:
# Green box in:  55599.0659183 55599.0859331
# Green box in:  55599.1340838 55599.1555859
# Green box in:  55599.2037713 55599.224903
# Green box in:  55599.2759299 55599.2941044
# Green box in:  55599.34685 55599.3632711
# Green box in:  55599.4173072 55599.4321831
# Green box in:  55599.4873882 55599.4972989
# Green box in:  55599.924732 55599.940042
# Total time in GTI 14273.660156412981
# AGILE mean 0.375
# AGILE median 0.0
# AGILE std 0.7696696072652383
# Fermi mean 2.9743589743589745
# Fermi median 3.0
# Fermi std 1.92609749284838
# Total time in GTI(bottom plot) 11700.0

# %%
apd.load_and_plot("AGILE3.ap4", "FERMI5.ap4", 55598.0, 55600.0, '/home/antonio/Desktop/task_ap3/dir_4_60.0_55597.0_55601.0', [55599.2, 55599.3])
# Out:
# Green box in:  55598.0028744 55598.0201924
# Green box in:  55598.071092 55598.0906322
# Green box in:  55598.1391706 55598.1604239
# Green box in:  55598.2078975 55598.2297873
# Green box in:  55598.2803686 55598.2990119
# Green box in:  55598.3514102 55598.3681785
# Green box in:  55598.4219079 55598.4372294
# Green box in:  55598.49207 55598.5038961
# Green box in:  55598.9299808 55598.9441507
# Green box in:  55598.9978338 55599.0156785
# Green box in:  55599.0659183 55599.0859331
# Green box in:  55599.1340838 55599.1555859
# Green box in:  55599.2037713 55599.224903
# Green box in:  55599.2759299 55599.2941044
# Green box in:  55599.34685 55599.3632711
# Green box in:  55599.4173072 55599.4321831
# Green box in:  55599.4873882 55599.4972989
# Green box in:  55599.924732 55599.940042
# Total time in GTI 30732.808312304318
# AGILE mean 0.22916666666666666
# AGILE median 0.0
# AGILE std 0.5921322211937858
# Fermi mean 3.045977011494253
# Fermi median 3.0
# ...
